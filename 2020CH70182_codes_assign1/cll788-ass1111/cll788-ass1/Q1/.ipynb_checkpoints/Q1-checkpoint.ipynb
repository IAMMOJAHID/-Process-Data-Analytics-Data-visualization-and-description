# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import kurtosis
from scipy.stats import skew
from statsmodels import robust
import statistics

# %%
data1 = "data1.xlsx"
data3 = "data3.xlsx"

# %%
read1 = pd.read_excel(data1)

# %%
read3 = pd.read_excel(data3)

# %%
#data1
read1.head()
# Out:
#           x         y
# 0  5.314170  3.830578
# 1  6.498186  4.849754
# 2  6.274251  3.946326
# 3  5.281705  3.986128
# 4  6.749456  6.152008

# %%
#data3
read3.head()
# Out:
#           x         y
# 0  7.302077  4.540255
# 1  5.005407  4.889362
# 2  7.550502  5.919873
# 3  7.450482  5.731041
# 4  4.686402  5.167912

# %%
#x in data1
list_x1 = list(read1['x'])

# %%
#y in data1
list_y1= list(read1['y'])

# %%
# x in data3
list_x3= list(read3['x'])

# %%
# y in data3
list_y3= list(read3['y'])

# %%
# scatter plot for data1
fig = plt.figure(figsize = (10, 10))
plt.scatter(list_x1, list_y1, s = 1, c = "red")  
plt.xlabel("x")
plt.ylabel("y")
plt.title("data1")
plt.show()

# %%
# scatter plot for data3
fig = plt.figure(figsize = (10, 10))
plt.scatter(list_x3, list_y3, s = 1, c = "blue")  
plt.xlabel("x")
plt.ylabel("y")
plt.title("data3")
plt.show()

# %%
#Histogram plot

# %%
sorted_list_x1=sorted(list_x1)

# %%
sorted_list_y1=sorted(list_y1)

# %%
sorted_list_x3=sorted(list_x3)

# %%
sorted_list_y3=sorted(list_y3)

# %%
plt.hist(sorted_list_x1)
# Out:
# (array([ 11.,  28.,  62.,  93., 116.,  94.,  58.,  30.,   7.,   1.]),
#  array([3.62363788, 4.19797856, 4.77231924, 5.34665992, 5.92100061,
#         6.49534129, 7.06968197, 7.64402266, 8.21836334, 8.79270402,
#         9.3670447 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(sorted_list_y1)
# Out:
# (array([ 11.,  20.,  45.,  81., 115., 116.,  71.,  27.,  11.,   3.]),
#  array([1.93118019, 2.53207305, 3.13296592, 3.73385879, 4.33475165,
#         4.93564452, 5.53653738, 6.13743025, 6.73832311, 7.33921598,
#         7.94010885]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(sorted_list_x3)
# Out:
# (array([  5.,  11.,   9.,  62., 220., 150.,  22.,  14.,   5.,   2.]),
#  array([-0.20840252,  1.16414018,  2.53668289,  3.90922559,  5.2817683 ,
#          6.654311  ,  8.02685371,  9.39939641, 10.77193912, 12.14448182,
#         13.51702453]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(sorted_list_y3)
# Out:
# (array([  4.,  15.,   6.,  49., 147., 184.,  64.,  14.,   9.,   8.]),
#  array([-1.25410036, -0.09476508,  1.0645702 ,  2.22390548,  3.38324076,
#          4.54257604,  5.70191132,  6.8612466 ,  8.02058188,  9.17991716,
#         10.33925244]),
#  <BarContainer object of 10 artists>)

# %%
# HaetMap data1
fig = plt.figure(figsize = (10, 10))
plt.hist2d(sorted_list_x1, sorted_list_y1, bins = 50)
plt.xlabel('x1')
plt.ylabel('y1')
plt.title("data1 heatmap")
cobar = plt.colorbar()
cobar.ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
# heatMap data3
fig = plt.figure(figsize = (10, 10))
plt.hist2d(sorted_list_x3, sorted_list_y3, bins = 50)
plt.xlabel('x3')
plt.ylabel('y3')
plt.title("data3 heatmap")
cobar = plt.colorbar()
cobar.ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
#data1
#left side box is of x
#right side box is of y
fig = plt.figure(figsize = (10, 10))
plt.boxplot([sorted_list_x1, sorted_list_y1]) 
plt.show()

# %%
#data3
#left side box is of x
#right side box is of y
fig = plt.figure(figsize = (10, 10))
plt.boxplot([sorted_list_x3, sorted_list_y3]) 
plt.show()

# %%
# Statistics

# %%
read1.describe()
# Out:
#                 x           y
# count  500.000000  500.000000
# mean     6.189743    4.792984
# std      0.986803    1.008197
# min      3.623638    1.931180
# 25%      5.553987    4.081464
# 50%      6.174278    4.824768
# 75%      6.857214    5.432380
# max      9.367045    7.940109

# %%
read1.median()
# Out:
# x    6.174278
# y    4.824768
# dtype: float64

# %%
read1.mean()
# Out:
# x    6.189743
# y    4.792984
# dtype: float64

# %%
mode_data1_x1=3*6.174278-2*6.189743
mode_data1_y1=3*4.824768-2*4.792984
mode_data1_x1, mode_data1_y1
# Out:
# (6.143348, 4.888336000000001)

# %%
read3.describe()
# Out:
#                 x           y
# count  500.000000  500.000000
# mean     6.332468    4.702896
# std      1.631735    1.623194
# min     -0.208403   -1.254100
# 25%      5.568981    3.968101
# 50%      6.304875    4.728847
# 75%      7.141603    5.532668
# max     13.517025   10.339252

# %%
read3.median()
# Out:
# x    6.304875
# y    4.728847
# dtype: float64

# %%
read3.mean()
# Out:
# x    6.332468
# y    4.702896
# dtype: float64

# %%
mode_data3_x3=3*6.304875-2*6.332468
mode_data3_y3=3*4.728847-2*4.728847
mode_data3_x3, mode_data3_y3
# Out:
# (6.249689, 4.728847)

# %%
# calculating Kurtosis for data1
data1_kx1 = kurtosis(list_x1)
data1_ky1 = kurtosis(list_y1)
data1_kx1, data1_ky1
# Out:
# (-0.20393248917210238, 0.09080227613137248)

# %%
# calculating Kurtosis for data3
data3_kx3 = kurtosis(list_x3)
data3_ky3 = kurtosis(list_y3)
data3_kx3, data3_ky3
# Out:
# (3.300987704861159, 2.4177973153847265)

# %%
# skewness for data1
skw_x1=skew(list_x1)
skw_y1=skew(list_y1)
skw_x1,skw_y1
# Out:
# (-0.0013613988672292099, -0.12074949274829158)

# %%
# skewness for data3
skw_x3=skew(list_x3)
skw_y3=skew(list_y3)
skw_x3,skw_y3
# Out:
# (0.04139808563058727, -0.08255310826792216)

# %%
# Outliers

# %%
# Outliers for data1 using Standard deviation

# %%
mean_x1=read1['x'].mean()
std_x1=read1['x'].std()
mean_y1=read1['y'].mean()
std_y1=read1['y'].std()

# %%
outl_x1=[]
norml_x1=[]
outl_y1=[]
norml_y1=[]
for i in range(len(list_x1)):
    if(abs((list_x1[i]-mean_x1)/std_x1) > 2 or abs((list_y1[i]-mean_y1)/std_y1) > 2):
        outl_x1.append(list_x1[i])
        outl_y1.append(list_y1[i])
    else:
        norml_x1.append(list_x1[i])
        norml_y1.append(list_y1[i])

# %%
fig = plt.figure(figsize = (10, 10))
plt.scatter(outl_x1, outl_y1, s = 8, c = "red")  
plt.scatter(norml_x1, norml_y1, s = 3, c = "blue")
plt.show()

# %%
# Outliers for data3 using Standard deviation

# %%
mean_x3=read3['x'].mean()
std_x3=read3['x'].std()
mean_y3=read3['y'].mean()
std_y3=read3['y'].std()

# %%
outl_x3=[]
norml_x3=[]
outl_y3=[]
norml_y3=[]
for i in range(len(list_x3)):
    if(abs((list_x3[i]-mean_x3)/std_x3) > 2 or abs((list_y3[i]-mean_y3)/std_y3) > 2):
        outl_x3.append(list_x3[i])
        outl_y3.append(list_y3[i])
    else:
        norml_x3.append(list_x3[i])
        norml_y3.append(list_y3[i])

# %%
fig = plt.figure(figsize = (10, 10))
plt.scatter(outl_x3, outl_y3, s = 8, c = "red")  
plt.scatter(norml_x3, norml_y3, s = 3, c = "blue")
plt.show()

# %%
# Outliers for data1 using MAD

# %%
def median(x):
    
    xs = sorted(x)
    
    n = len(xs)
    
    if (n%2)!=0:
        md = xs[(n + 1)/2 - 1]
    else:
        md = (xs[int(n/2)] + xs[int(n/2) - 1])/2
    return md

# %%
median_x1=read1['x'].median()
median_y1=read1['y'].median()
temp_x1=[]
temp_y1=[]
for i in range(len(list_x1)):
    temp_x1.append(abs(list_x1[i]-median_x1))
    temp_y1.append(abs(list_y1[i]-median_y1))
MAD_x1=median(temp_x1)
MAD_y1=median(temp_y1)

# %%
nrml_x1=[]
ot_x1=[]
nrml_y1=[]
ot_y1=[]
for i in range(len(list_x1)):
    if( abs(0.6745*(list_x1[i]-median_x1)/MAD_x1)>3 or abs(0.6745*(list_y1[i]-median_y1)/MAD_y1)>3 ):
        ot_x1.append(list_x1[i])
        ot_y1.append(list_y1[i])
    else:
        nrml_x1.append(list_x1[i])
        nrml_y1.append(list_y1[i])

# %%
fig = plt.figure(figsize = (10, 10))
plt.scatter(ot_x1, ot_y1, s = 8, c = "red")  
plt.scatter(nrml_x1, nrml_y1, s = 3, c = "blue")
plt.show()

# %%
# Outliers for data3 using MAD

# %%
median_x3=read3['x'].median()
median_y3=read3['y'].median()
temp_x3=[]
temp_y3=[]
for i in range(len(list_x3)):
    temp_x3.append(abs(list_x3[i]-median_x3))
    temp_y3.append(abs(list_y3[i]-median_y3))
MAD_x3=median(temp_x3)
MAD_y3=median(temp_y3)

# %%
nrml_x3=[]
ot_x3=[]
nrml_y3=[]
ot_y3=[]

for i in range(len(list_x3)):
    if( abs(0.6745*(list_x3[i]-median_x3)/MAD_x3)>3 or abs(0.6745*(list_y3[i]-median_y3)/MAD_y3)>3 ):
        ot_x3.append(list_x3[i])
        ot_y3.append(list_y3[i])
    else:
        nrml_x3.append(list_x3[i])
        nrml_y3.append(list_y3[i])

# %%
fig = plt.figure(figsize = (10, 10))
plt.scatter(ot_x3, ot_y3, s = 8, c = "red")  
plt.scatter(nrml_x3, nrml_y3, s = 3, c = "blue")
plt.show()
